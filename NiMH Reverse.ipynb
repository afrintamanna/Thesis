# %%
import pandas as pd 
import numpy as np 
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def readingfiles(filename):
   
    station_df = pd.read_fwf(filename, colspecs='infer', widths=None,skiprows=(np.arange(0,18,1)),encoding="latin1",na_values = "NAN",low_memory=True)
    return(station_df)

# %%
file_name = "nimh1-0100-1.txt"
ni1mh1001 = file_name
ni1mh1001 = readingfiles(ni1mh1001)

file_name = "nimh1-0100-2.txt"
ni1mh1002 = file_name
ni1mh1002 = readingfiles(ni1mh1002)

file_name = "nimh1-0200-1.txt"
ni1mh2001 = file_name
ni1mh2001 = readingfiles(ni1mh2001)

file_name = "nimh1-0200-2.txt"
ni1mh2002 = file_name
ni1mh2002 = readingfiles(ni1mh2002)

file_name = "nimh1-0500-1.txt"
ni1mh5001 = file_name
ni1mh5001 = readingfiles(ni1mh5001)

file_name = "nimh1-0500-2.txt"
ni1mh5002 = file_name
ni1mh5002  = readingfiles(ni1mh5002)

file_name = "nimh1-1000-1.txt"
ni1mh10001 = file_name
ni1mh10001 = readingfiles(ni1mh10001)

file_name = "nimh1-1000-2.txt"
ni1mh10002 = file_name
ni1mh10002  = readingfiles(ni1mh10002)

file_name = "nimh1-2000-1.txt"
ni1mh20001 = file_name
ni1mh20001 = readingfiles(ni1mh20001)

file_name = "nimh1-2000-2.txt"
ni1mh20002 = file_name
ni1mh20002  = readingfiles(ni1mh20002)



file_name = "nimh2-0100-1.txt"
ni2mh1001 = file_name
ni2mh1001 = readingfiles(ni2mh1001)

file_name = "nimh2-0100-2.txt"
ni2mh1002 = file_name
ni2mh1002 = readingfiles(ni2mh1002)

file_name = "nimh2-0200-1.txt"
ni2mh2001 = file_name
ni2mh2001 = readingfiles(ni2mh2001)

file_name = "nimh2-0200-2.txt"
ni2mh2002 = file_name
ni2mh2002 = readingfiles(ni2mh2002)

file_name = "nimh2-0500-1.txt"
ni2mh5001 = file_name
ni2mh5001 = readingfiles(ni2mh5001)

file_name = "nimh2-0500-2.txt"
ni2mh5002 = file_name
ni2mh5002  = readingfiles(ni2mh5002)

file_name = "nimh2-1000-1.txt"
ni2mh10001 = file_name
ni2mh10001 = readingfiles(ni2mh10001)

file_name = "nimh2-1000-2.txt"
ni2mh10002 = file_name
ni2mh10002  = readingfiles(ni2mh10002)

file_name = "nimh2-2000-1.txt"
ni2mh20001 = file_name
ni2mh20001 = readingfiles(ni2mh20001)

file_name = "nimh2-2000-2.txt"
ni2mh20002 = file_name
ni2mh20002  = readingfiles(ni2mh20002)


file_name = "nimh3-0100-1.txt"
ni3mh1001 = file_name
ni3mh1001 = readingfiles(ni3mh1001)

file_name = "nimh3-0100-2.txt"
ni3mh1002 = file_name
ni3mh1002 = readingfiles(ni3mh1002)

file_name = "nimh3-0200-1.txt"
ni3mh2001 = file_name
ni3mh2001 = readingfiles(ni3mh2001)

file_name = "nimh3-0200-2.txt"
ni3mh2002 = file_name
ni3mh2002 = readingfiles(ni3mh2002)

file_name = "nimh3-0500-1.txt"
ni3mh5001 = file_name
ni3mh5001 = readingfiles(ni3mh5001)

file_name = "nimh3-0500-2.txt"
ni3mh5002 = file_name
ni3mh5002  = readingfiles(ni3mh5002)

file_name = "nimh3-1000-1.txt"
ni3mh10001 = file_name
ni3mh10001 = readingfiles(ni3mh10001)

file_name = "nimh3-1000-2.txt"
ni3mh10002 = file_name
ni3mh10002  = readingfiles(ni3mh10002)

file_name = "nimh3-2000-1.txt"
ni3mh20001 = file_name
ni3mh20001 = readingfiles(ni3mh20001)

file_name = "nimh3-2000-2.txt"
ni3mh20002 = file_name
ni3mh20002  = readingfiles(ni3mh20002)


file_name = "nimh4-0100-1.txt"
ni4mh1001 = file_name
ni4mh1001 = readingfiles(ni4mh1001)

file_name = "nimh4-0100-2.txt"
ni4mh1002 = file_name
ni4mh1002 = readingfiles(ni4mh1002)

file_name = "nimh4-0200-1.txt"
ni4mh2001 = file_name
ni4mh2001 = readingfiles(ni4mh2001)

file_name = "nimh4-0200-2.txt"
ni4mh2002 = file_name
ni4mh2002 = readingfiles(ni4mh2002)

file_name = "nimh4-0500-1.txt"
ni4mh5001 = file_name
ni4mh5001 = readingfiles(ni4mh5001)

file_name = "nimh4-0500-2.txt"
ni4mh5002 = file_name
ni4mh5002  = readingfiles(ni4mh5002)

file_name = "nimh4-1000-1.txt"
ni4mh10001 = file_name
ni4mh10001 = readingfiles(ni4mh10001)

file_name = "nimh4-1000-2.txt"
ni4mh10002 = file_name
ni4mh10002  = readingfiles(ni4mh10002)

file_name = "nimh4-2000-1.txt"
ni4mh20001 = file_name
ni4mh20001 = readingfiles(ni4mh20001)

file_name = "nimh4-2000-2.txt"
ni4mh20002 = file_name
ni4mh20002  = readingfiles(ni4mh20002)

# %%
ni1mh1001["impedance/Ohm"] = ni1mh1001["impedance/Ohm"]*1000
ni1mh1002["impedance/Ohm"] = ni1mh1002["impedance/Ohm"]*1000
ni1mh2001["impedance/Ohm"] = ni1mh2001["impedance/Ohm"]*1000
ni1mh2002["impedance/Ohm"] = ni1mh2002["impedance/Ohm"]*1000
ni1mh5001["impedance/Ohm"] = ni1mh5001["impedance/Ohm"]*1000
ni1mh5002["impedance/Ohm"] = ni1mh5002["impedance/Ohm"]*1000
ni1mh10001["impedance/Ohm"] = ni1mh1001["impedance/Ohm"]*1000
ni1mh10002["impedance/Ohm"] = ni1mh10002["impedance/Ohm"]*1000
ni1mh20001["impedance/Ohm"] = ni1mh20001["impedance/Ohm"]*1000
ni1mh20002["impedance/Ohm"] = ni1mh20002["impedance/Ohm"]*1000
ni2mh1001["impedance/Ohm"] = ni2mh1001["impedance/Ohm"]*1000
ni2mh1002["impedance/Ohm"] = ni2mh1002["impedance/Ohm"]*1000
ni2mh2001["impedance/Ohm"] = ni2mh2001["impedance/Ohm"]*1000
ni2mh2002["impedance/Ohm"] = ni2mh2002["impedance/Ohm"]*1000
ni2mh5001["impedance/Ohm"] = ni2mh5001["impedance/Ohm"]*1000
ni2mh5002["impedance/Ohm"] = ni2mh5002["impedance/Ohm"]*1000
ni2mh10001["impedance/Ohm"] = ni2mh1001["impedance/Ohm"]*1000
ni2mh10002["impedance/Ohm"] = ni2mh10002["impedance/Ohm"]*1000
ni2mh20001["impedance/Ohm"] = ni2mh20001["impedance/Ohm"]*1000
ni2mh20002["impedance/Ohm"] = ni2mh20002["impedance/Ohm"]*1000
ni3mh1001["impedance/Ohm"] = ni3mh1001["impedance/Ohm"]*1000
ni3mh1002["impedance/Ohm"] = ni3mh1002["impedance/Ohm"]*1000
ni3mh2001["impedance/Ohm"] = ni3mh2001["impedance/Ohm"]*1000
ni3mh2002["impedance/Ohm"] = ni3mh2002["impedance/Ohm"]*1000
ni3mh5001["impedance/Ohm"] = ni3mh5001["impedance/Ohm"]*1000
ni3mh5002["impedance/Ohm"] = ni3mh5002["impedance/Ohm"]*1000
ni3mh10001["impedance/Ohm"] = ni3mh1001["impedance/Ohm"]*1000
ni3mh10002["impedance/Ohm"] = ni3mh10002["impedance/Ohm"]*1000
ni3mh20001["impedance/Ohm"] = ni3mh20001["impedance/Ohm"]*1000
ni3mh20002["impedance/Ohm"] = ni3mh20002["impedance/Ohm"]*1000
ni4mh1001["impedance/Ohm"] = ni4mh1001["impedance/Ohm"]*1000
ni4mh1002["impedance/Ohm"] = ni4mh1002["impedance/Ohm"]*1000
ni4mh2001["impedance/Ohm"] = ni4mh2001["impedance/Ohm"]*1000
ni4mh2002["impedance/Ohm"] = ni4mh2002["impedance/Ohm"]*1000
ni4mh5001["impedance/Ohm"] = ni4mh5001["impedance/Ohm"]*1000
ni4mh5002["impedance/Ohm"] = ni4mh5002["impedance/Ohm"]*1000
ni4mh10001["impedance/Ohm"] = ni4mh1001["impedance/Ohm"]*1000
ni4mh10002["impedance/Ohm"] = ni4mh10002["impedance/Ohm"]*1000
ni4mh20001["impedance/Ohm"] = ni4mh20001["impedance/Ohm"]*1000
ni4mh20002["impedance/Ohm"] = ni4mh20002["impedance/Ohm"]*1000

# %%
def setting(file): 
    file.index = file["Frequency/Hz"]
    c = file["impedance/Ohm"]
    return(c)
eneloop1_10ma = setting(ni1mh10)
eneloop2_10ma = setting(ni2mh10)
eneloop3_10ma = setting(ni3mh10)
eneloop1_100ma_1 = setting(ni1mh1001)
eneloop1_100ma_2 = setting(ni1mh1002)
eneloop1_100ma_3 = setting(ni1mh1003)
eneloop1_100ma_4 = setting(ni1mh1004)
eneloop2_100ma_1 = setting(ni2mh1001)
eneloop2_100ma_2 = setting(ni2mh1002)
eneloop2_100ma_3 = setting(ni2mh1003)
eneloop2_100ma_4 = setting(ni2mh1004)
eneloop3_100ma_1 = setting(ni3mh1001)
eneloop3_100ma_2 = setting(ni3mh1002)
eneloop3_100ma_3 = setting(ni3mh1003)
eneloop3_100ma_4 = setting(ni3mh1004)
eneloop4_100ma_1 = setting(ni4mh1001)
eneloop4_100ma_2 = setting(ni4mh1002)
eneloop4_100ma_3 = setting(ni4mh1003)
eneloop4_100ma_4 = setting(ni4mh1004)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7a044c8903fe> in <module>
#       3     c = file["impedance/Ohm"]
#       4     return(c)
# ----> 5 eneloop1_10ma = setting(ni1mh10)
#       6 eneloop2_10ma = setting(ni2mh10)
#       7 eneloop3_10ma = setting(ni3mh10)
#
# NameError: name 'ni1mh10' is not defined

# %%
ni4mh20001
# Out:
#     Number  Frequency/Hz  impedance/Ohm  Phase/deg  Significance  Time/s
# 0        1   1286.400000         78.164       6.73         1.000     0.0
# 1        2   1712.800000         78.614       9.06         1.000     1.7
# 2        3   2280.600000         79.458      12.06         1.000     2.7
# 3        4   3036.700000         80.975      15.93         1.000     3.7
# 4        5   4043.300000         83.603      20.74         1.000     4.7
# 5        6   5383.700000         88.048      26.54         0.999     5.8
# 6        7   7168.400000         95.282      33.22         0.999     6.8
# 7        8   9544.600000        106.580      40.38         1.000     7.9
# 8        9  12709.000000        123.460      47.45         0.999     9.0
# 9       10  16922.000000        147.570      53.97         1.000    10.0
# 10      11  22531.000000        180.810      59.63         0.999    11.1
# 11      12  30000.000000        225.490      64.37         0.999    12.1
# ...

# %%
fig1, ax1 = plt.subplots(figsize = (10,4), dpi = 600)

ni1mh1001.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="blue",marker='x',linewidth=0.2 ,markersize = 5,label= "NiMH 1")
ni2mh1001.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="yellow",marker='o',linewidth=0.2 ,markersize = 5,label= "NiMH 2")
ni3mh1001.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="red",marker='s',linewidth=0.2 ,markersize = 5,label= "NiMH 3")
ni4mh1001.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="green",marker='p',linewidth=0.2 ,markersize = 5,label= "NiMH 4")



ax1.grid(True)
ax1.set_xscale('log')
#ax1.set_title("Impedance vs Frequency of VARTA NiMH 1")
plt.ylabel("Impedance/mOhm")
plt.xlabel("Frequency/Hz")
plt.xlim([10**-1.5, 10**4.5])
plt.ylim([70, 150])
plt.savefig("nimh1234-100ma.jpeg")
plt.show()

# %%
fig1, ax1 = plt.subplots(figsize = (10,4), dpi = 600)

ni1mh2001.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="blue",marker='x',linewidth=0.2 ,markersize = 5,label= "NiMH 1")
ni2mh2001.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="yellow",marker='o',linewidth=0.2 ,markersize = 5,label= "NiMH 2")
ni3mh2001.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="red",marker='s',linewidth=0.2 ,markersize = 5,label= "NiMH 3")
ni4mh2001.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="green",marker='p',linewidth=0.2 ,markersize = 5,label= "NiMH 4")



ax1.grid(True)
ax1.set_xscale('log')
#ax1.set_title("Impedance vs Frequency of VARTA NiMH 1")
plt.ylabel("Impedance/mOhm")
plt.xlabel("Frequency/Hz")
plt.xlim([10**-1.5, 10**4.5])
plt.ylim([70, 150])
plt.savefig("nimh1234-200ma.jpeg")
plt.show()

# %%
fig1, ax1 = plt.subplots(figsize = (10,4), dpi = 600)

ni1mh5001.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="blue",marker='x',linewidth=0.2 ,markersize = 5,label= "NiMH 1")
ni2mh5001.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="yellow",marker='o',linewidth=0.2 ,markersize = 5,label= "NiMH 2")
ni3mh5001.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="red",marker='s',linewidth=0.2 ,markersize = 5,label= "NiMH 3")
ni4mh5001.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="green",marker='p',linewidth=0.2 ,markersize = 5,label= "NiMH 4")



ax1.grid(True)
ax1.set_xscale('log')
#ax1.set_title("Impedance vs Frequency of VARTA NiMH 1")
plt.ylabel("Impedance/mOhm")
plt.xlabel("Frequency/Hz")
plt.xlim([10**-1.5, 10**4.5])
plt.ylim([70, 115])
plt.savefig("nimh1234-500ma.jpeg")
plt.show()

# %%
fig1, ax1 = plt.subplots(figsize = (10,4), dpi = 600)

ni1mh10002.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="blue",marker='x',linewidth=0.2 ,markersize = 5,label= "NiMH 1")
ni2mh10002.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="yellow",marker='o',linewidth=0.2 ,markersize = 5,label= "NiMH 2")
ni3mh10002.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="red",marker='s',linewidth=0.2 ,markersize = 5,label= "NiMH 3")
ni4mh10002.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="green",marker='p',linewidth=0.2 ,markersize = 5,label= "NiMH 3")



ax1.grid(True)
ax1.set_xscale('log')
#ax1.set_title("Impedance vs Frequency of VARTA NiMH 1")
plt.ylabel("Impedance/mOhm")
plt.xlabel("Frequency/Hz")
plt.xlim([10**-1.5, 10**4.5])
plt.ylim([70, 115])
plt.savefig("nimh1234-1000ma.jpeg")
plt.show()

# %%
fig1, ax1 = plt.subplots(figsize = (10,4), dpi = 600)

ni1mh20002.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="blue",marker='x',linewidth=0.2 ,markersize = 5,label= "NiMH 1")
ni2mh20002.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="yellow",marker='o',linewidth=0.2 ,markersize = 5,label= "NiMH 2")
ni3mh20002.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="red",marker='s',linewidth=0.2 ,markersize = 5,label= "NiMH 3")
ni4mh20002.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="green",marker='p',linewidth=0.2 ,markersize = 5,label= "NiMH 4")



ax1.grid(True)
ax1.set_xscale('log')
#ax1.set_title("Impedance vs Frequency of VARTA NiMH 1")
plt.ylabel("Impedance/mOhm")
plt.xlabel("Frequency/Hz")
plt.xlim([10**-1.5, 10**4.5])
plt.ylim([70, 115])
plt.savefig("nimh1234-2000ma.jpeg")
plt.show()

# %%
fig1, ax1 = plt.subplots(figsize = (10,4), dpi = 600)

ni1mh1001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="blue",marker='x',linewidth=0.2 ,markersize = 5,label= "NiMH 1")
ni2mh1001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="yellow",marker='o',linewidth=0.2 ,markersize = 5,label= "NiMH 2")
ni3mh1001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="red",marker='s',linewidth=0.2 ,markersize = 5,label= "NiMH 3")
ni4mh1001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="green",marker='p',linewidth=0.2 ,markersize = 5,label= "NiMH 4")



ax1.grid(True)
ax1.set_xscale('log')
#ax1.set_title("Impedance vs Frequency of VARTA NiMH 1")
plt.ylabel("Phase/deg")
plt.xlabel("Frequency/Hz")
plt.xlim([10**-1.5, 10**3.5])
plt.ylim([-3, 8])
plt.savefig("nimh1234-100maPhase.jpeg")
plt.show()

# %%
fig1, ax1 = plt.subplots(figsize = (10,4), dpi = 600)

ni1mh2001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="blue",marker='x',linewidth=0.2 ,markersize = 5,label= "NiMH 1")
ni2mh2001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="yellow",marker='o',linewidth=0.2 ,markersize = 5,label= "NiMH 2")
ni3mh2001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="red",marker='s',linewidth=0.2 ,markersize = 5,label= "NiMH 3")
ni4mh2001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="green",marker='p',linewidth=0.2 ,markersize = 5,label= "NiMH 4")



ax1.grid(True)
ax1.set_xscale('log')
#ax1.set_title("Impedance vs Frequency of VARTA NiMH 1")
plt.ylabel("Phase/deg")
plt.xlabel("Frequency/Hz")
plt.xlim([10**-1.5, 10**3.5])
plt.ylim([-3, 8])
plt.savefig("nimh1234-200maPhase.jpeg")
plt.show()

# %%
fig1, ax1 = plt.subplots(figsize = (10,4), dpi = 600)

ni1mh5001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="blue",marker='x',linewidth=0.2 ,markersize = 5,label= "NiMH 1")
ni2mh5001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="yellow",marker='o',linewidth=0.2 ,markersize = 5,label= "NiMH 2")
ni3mh5001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="red",marker='s',linewidth=0.2 ,markersize = 5,label= "NiMH 3")
ni4mh5001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="green",marker='p',linewidth=0.2 ,markersize = 5,label= "NiMH 4")



ax1.grid(True)
ax1.set_xscale('log')
#ax1.set_title("Impedance vs Frequency of VARTA NiMH 1")
plt.ylabel("Phase/deg")
plt.xlabel("Frequency/Hz")
plt.xlim([10**-1.5, 10**3.5])
plt.ylim([-3, 8])
plt.savefig("nimh1234-500maPhase.jpeg")
plt.show()

# %%
fig1, ax1 = plt.subplots(figsize = (10,4), dpi = 600)

ni1mh10001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="blue",marker='x',linewidth=0.2 ,markersize = 5,label= "NiMH 1")
ni2mh10001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="yellow",marker='o',linewidth=0.2 ,markersize = 5,label= "NiMH 2")
ni3mh10001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="red",marker='s',linewidth=0.2 ,markersize = 5,label= "NiMH 3")
ni4mh10001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="green",marker='p',linewidth=0.2 ,markersize = 5,label= "NiMH 4")



ax1.grid(True)
ax1.set_xscale('log')
#ax1.set_title("Impedance vs Frequency of VARTA NiMH 1")
plt.ylabel("Phase/deg")
plt.xlabel("Frequency/Hz")
plt.xlim([10**-1.5, 10**3.5])
plt.ylim([-2, 8])
plt.savefig("nimh1234-1000maPhase.jpeg")
plt.show()

# %%
fig1, ax1 = plt.subplots(figsize = (10,4), dpi = 600)

ni1mh20001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="blue",marker='x',linewidth=0.2 ,markersize = 5,label= "NiMH 1")
ni2mh20001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="yellow",marker='o',linewidth=0.2 ,markersize = 5,label= "NiMH 2")
ni3mh20001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="red",marker='s',linewidth=0.2 ,markersize = 5,label= "NiMH 3")
ni4mh20001.plot(ax = ax1, y='Phase/deg',x='Frequency/Hz',c="green",marker='p',linewidth=0.2 ,markersize = 5,label= "NiMH 4")



ax1.grid(True)
ax1.set_xscale('log')
#ax1.set_title("Impedance vs Frequency of VARTA NiMH 1")
plt.ylabel("Phase/deg")
plt.xlabel("Frequency/Hz")
plt.xlim([10**-1.5, 10**3.5])
plt.ylim([-3.5, 9])
plt.savefig("nimh1234-2000maPhase.jpeg")
plt.show()

# %%
fig1, ax1 = plt.subplots(figsize = (10,4), dpi = 600)
ax2= ax1.twinx()

ni1mh1001.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="blue",marker='x',linewidth=0.2 ,markersize = 5,label= "NiMH 1")
ni2mh1001.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="yellow",marker='o',linewidth=0.2 ,markersize = 5,label= "NiMH 2")
ni3mh1001.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="red",marker='s',linewidth=0.2 ,markersize = 5,label= "NiMH 3")
ni4mh1001.plot(ax = ax1, y='impedance/Ohm',x='Frequency/Hz',c="green",marker='p',linewidth=0.2 ,markersize = 5,label= "NiMH 4")

ni1mh1001.plot(ax = ax2, y='Phase/deg',x='Frequency/Hz',c="blue",marker='x',linewidth=0.2 ,markersize = 5)
ni2mh1001.plot(ax = ax2, y='Phase/deg',x='Frequency/Hz',c="yellow",marker='o',linewidth=0.2 ,markersize = 5)
ni3mh1001.plot(ax = ax2, y='Phase/deg',x='Frequency/Hz',c="red",marker='s',linewidth=0.2 ,markersize = 5)
ni4mh1001.plot(ax = ax2, y='Phase/deg',x='Frequency/Hz',c="green",marker='p',linewidth=0.2 ,markersize = 5)

ax1.grid(True)
ax1.set_xscale('log')
#ax1.set_title("Impedance vs Frequency of VARTA NiMH 1")
ax2.set_ylabel("Phase/deg")
ax1.set_ylabel("Impedance/mOhm")
#plt.ylabel("Impedance/mOhm")
#plt.ylabel("Phase/deg")
plt.xlabel("Frequency/Hz")
plt.xlim([10**-1.5, 10**3.5])
ax2.set_ylim(-10, 110)
ax1.set_ylim(-10, 110)
#plt.ylim([-10, 110])
plt.savefig("nimh1234-100mapi.jpeg")
plt.show()
